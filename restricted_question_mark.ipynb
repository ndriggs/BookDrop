# %%
import requests
from bs4 import BeautifulSoup

# %%
signin_url = "https://sellercentral.amazon.com/ap/signin?clientContext=133-6592574-4190731&openid.return_to=https%3A%2F%2Fsellercentral.amazon.com%2Fhome&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=sc_na_amazon_v2&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&ssoResponse=eyJ6aXAiOiJERUYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiQTI1NktXIn0.MKiRrgriO3uLOKHiJch5fI0RRTvrKskYGD6xpcfOE59bcZswafnTpw.0QtLhxJL3OSfFpAu.qsTKEg89PBa5mZ01-9NtMJMCp7L1XEEy89uD64WmIhLMt_ybT8UqTU63jvx2GxyuF3lLSsieTb9-5o_zMycXkFls0LQKp4jakkIVlPYYAo-3j1w-QHBadlafoOunHTkz8QwI_b8OIlbOQ6_Iy__rMpyx_Ua4knohD43o8Zxo0jOtXMm9vOo1qXqVXwOa7AeNxSK-ZiAo33Q9p7FUMO0hxn6etjuavkc7q8go3o4I60zlDTLl3jgyV6A21PZJBF9nnNTZ8g.Ovqk4dFmUHH8HcWaRs2hvQ" 
url = "https://sellercentral.amazon.com/product-search?ref=xx_addlisting_dnav_xx"

# %%
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36',
    'authority': 'sellercentral.amazon.com',
    'method': 'POST',
    'path': '/ap/signin',
    'scheme': 'https',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    #'accept-encoding': ['gzip', 'deflate', 'br'],
    'cache-control': 'max-age=0',
    'content-length': '3991',
    'content-type': 'application/x-www-form-urlencoded',
    'cookie': 'signin-sso-state-us=f35d248c-92ba-4228-8e20-84077bce11a1; s_fid=29B6B31A6B6E68D1-2A40C56785379281; regStatus=registered; aws-priv=eyJ2IjoxLCJldSI6MCwic3QiOjB9; aws-target-static-id=1568127418917-479395; aws-target-data=%7B%22support%22%3A%221%22%7D; aws-ubid-main=515-1476224-7573362; session-id=137-7893640-3239625; ubid-main=133-6592574-4190731; x-wl-uid=1/dW9Y8NdxoH2DpKyUulU0hHhoFSPViMJBo9Khpu7VCkZp7WTyJJNfWJPgZW1PkkPuuuvzYIfJvdH17YpovmqPOtBXZ8cen5rXdSavNXjq3FmtCJKUCjcrvrkkO8viLQh+UexFfplVa8=; aws-business-metrics-last-visit=1570761582317; aws-target-visitor-id=1568127418928-928122.28_0; i18n-prefs=USD; s_pers=%20s_nr%3D1588711055180-Repeat%7C1596487055180%3B; s_vn=1599509589845%26vn%3D40; aws-userInfo=%7B%22arn%22%3A%22arn%3Aaws%3Aiam%3A%3A467097711428%3Aroot%22%2C%22alias%22%3A%22%22%2C%22username%22%3A%22BookDrop%22%2C%22keybase%22%3A%22MIhZrCgO0ZiA91l3KG%2FP0i%2B26mgMePp%2FGtfRjQSA1Jc%5Cu003d%22%2C%22issuer%22%3A%22http%3A%2F%2Fsignin.aws.amazon.com%2Fsignin%22%2C%22signinType%22%3A%22PUBLIC%22%7D; s_dslv=1588787963647; s_nr=1588787963653-Repeat; skin=noskin; sid="w7p9JIxMXxI7P6xmZUkl1g==|TfXWDs3JDaTYQPHU6zrMkNLAU6Gp4mBJGGY+qW3OBsU="; sst-main=Sst1|PQEqZ99ovQii-fb3xH8s7xYyBwCqvjvP3mOEKBz6B_OGgzs30nZLiuVrsi9lDWsDw74T6HeTwI4sLPte91M9APElNORMUUPvCwPRPH2MbXbHZ-iYzjW1sFEJoP5s-fj4uodXjeSq2Iou9Ul7xfC-YX7yBZcmSlR-kRi-HJFxsZlDWl4W8JPWHrrt_BhFWV0FmGsI6fX5IibGiRdibkZT9T-BGGf9ftJjYjvkEaEd8SqlFQaSqdBAy3lJRkBUPyeeDf0m; session-token=cNSSX8HKzJrM+EwiJZpvuJl+IQbRfBL4YDmC7AZPTasupuCu40aJThRiymf+UQ19IKmY7gKBO8xekTXOUMEt56NCmemJYRI4DFU9PHL6PlMMAv9iqISK1KUdEkYb8XSQplQY2AdvusxiBrLHO6TQe5bf9ZKhhZrClHWGHyQPb8LQoTElc/LumUGoxjHXsPdAEGIq0pX7q7BB56l7fF8UVMRuMS+KVOzW; session-id-time=2220897649l; csm-hit=tb:ETEGX8KATTXKW7P24YNP+s-WN1YT68PHWKX0NJ5T1GN|1590178804602&t:1590178804602&adb:adblk_no',
    'origin': 'https://sellercentral.amazon.com',
    'referer': 'https://sellercentral.amazon.com/ap/signin?clientContext=133-6592574-4190731&openid.return_to=https%3A%2F%2Fsellercentral.amazon.com%2Fhome&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=sc_na_amazon_v2&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&ssoResponse=eyJ6aXAiOiJERUYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiQTI1NktXIn0.AH-HKZvYC677y2VJyA1gUE9ZImqRX7lX986FmqOVVNSDBsoi-M0Cwg.CEa3N_ESlQ72zjPb.YTUxwkT42ELcxrRUKtJaMRt2OIivYXzgikcxBbW9omIQIXXMIl13CJ3O_P_MEVJRmCeiy4xaRBiR5VqyZNtYiHvHjAFL3XnmXr0hboUfJlA_3kJfmcxCCkGTqy-QGaO1-JOM9-l4FRd0Ii-8ZYXJboJfyUh4IULm1NCtbNsh8CqP1auYIssw9qOp3NYE1_KO-KCJ9FHHbKnjVvqFSbL2q6LNIzJKsXn-kY3037z6GBegCcAoaQ4wN8Py5khzJuraDxRCBlqFYRFdZnJb91wpUp1fkqcniMA3Jrk.9rGPCwAOHoCNRa3TyJTehg',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1'
    
    #'origin': url,
    #'referer': url + signin_path
}

# %%
s = requests.Session()
response = s.get(signin_url)
soup = BeautifulSoup(response.content, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="a-no-js" data-19ax5a9jf="dingo">\n <head>\n  <script>\n   var aPageStart = (new Date()).getTime();\n  </script>\n  <meta charset="utf-8"/>\n  <title dir="ltr">\n   Amazon Sign-In\n  </title>\n  <link href="https://images-na.ssl-images-amazon.com/images/I/61Brdu0o6LL._RC|11Fd9tJOdtL.css,21y5jWQoUML.css,31Q3id-QR0L.css,31P8A7PnBZL.css_.css?AUIClients/AmazonUI#us.not-trident" rel="stylesheet"/>\n  <link href="https://images-na.ssl-images-amazon.com/images/I/01SdjaY0ZsL._RC|419sIPk+mYL.css,41DvNOWXxOL.css_.css?AUIClients/AuthenticationPortalAssets" rel="stylesheet"/>\n  <link href="https://images-na.ssl-images-amazon.com/images/I/11E08O3eXDL.css?AUIClients/CVFAssets" rel="stylesheet"/>\n  <script>\n   (function(f,h,R,A){function G(a){v&&v.tag&&v.tag(q(":","aui",a))}function x(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function m(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function y(a,b,c){a.addEventListener?a.ad
# ...

# %%
cookies = dict(response.cookies)
token = soup.find("input", {"name":"appActionToken"})["value"]
payload = {"rememberMe":"true", "email":"nathaniel@bookdrop.com", "password":"izeh+J5Q+/fXD_?", "appActionToken":token}

# %%
login_request = s.post(signin_url, headers=headers, data=payload, cookies=cookies)

# %%
login_request.status_code
# Out:
# 200

# %%
login_request.content
# Out:
# b'\n\n\n\n<!doctype html><html class="a-no-js" data-19ax5a9jf="dingo">\n  <head>\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);\n\n\n    var ue_err_chan = \'jserr-rw\';\n(function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL="
# ...

# %%
login_request.url
# Out:
# 'https://sellercentral.amazon.com/ap/signin?clientContext=133-6592574-4190731&openid.return_to=https%3A%2F%2Fsellercentral.amazon.com%2Fhome&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=sc_na_amazon_v2&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&ssoResponse=eyJ6aXAiOiJERUYiLCJlbmMiOiJBMjU2R0NNIiwiYWxnIjoiQTI1NktXIn0.MKiRrgriO3uLOKHiJch5fI0RRTvrKskYGD6xpcfOE59bcZswafnTpw.0QtLhxJL3OSfFpAu.qsTKEg89PBa5mZ01-9NtMJMCp7L1XEEy89uD64WmIhLMt_ybT8UqTU63jvx2GxyuF3lLSsieTb9-5o_zMycXkFls0LQKp4jakkIVlPYYAo-3j1w-QHBadlafoOunHTkz8QwI_b8OIlbOQ6_Iy__rMpyx_Ua4knohD43o8Zxo0jOtXMm9vOo1qXqVXwOa7AeNxSK-ZiAo33Q9p7FUMO0hxn6etjuavkc7q8go3o4I60zlDTLl3jgyV6A21PZJBF9nnNTZ8g.Ovqk4dFmUHH8HcWaRs2hvQ'

# %%
Request URL: https://sellercentral.amazon.com/ap/signin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36
    
"rememberMe":"true",

# %%
# so if just do normal header can get it to input the data into the form but not submit it...
# maybe like that one stack overflow said it's something wrong with the url I'm using 
# https://stackoverflow.com/questions/35569447/how-to-click-submit-button-in-a-form
# the latest login content is from using the "full" header, can't quite tell what type of page it is
# use the network thing and inspect the signin POST and maybe try and find the right url there, can 
# first go through the process for the NY 529 thing and see where they found the correct url
